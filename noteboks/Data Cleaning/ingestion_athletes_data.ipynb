# %%
# %run "../Includes/Function"

# %%
display(dbutils.fs.ls('/mnt/olympicstokyoadlssa/raw/Dataset'))

# %%
from pyspark.sql.types import *
athletes_schema=StructType([
    StructField('Name',StringType(),True),
    StructField('NOC',StringType(),True),
    StructField('Discipline',StringType(),True)
])

# %%
athletes_raw=spark.read.format('csv')\
    .schema(athletes_schema)\
        .option('header',True)\
        .load('dbfs:/mnt/olympicstokyoadlssa/raw/Dataset/Athletes.csv')
display(athletes_raw)

# %%
display(athletes_raw.count())

# %%
athletes_df1=remove_accents_df(athletes_raw)

# %%
display(athletes_raw.groupBy('Discipline').count().orderBy('Discipline'))

# %%
athletes_raw.write.mode('overwrite').parquet('/mnt/olympicstokyoadlssa/processed/Athletes_processed')

# %%
spark.read.parquet('/mnt/olympicstokyoadlssa/processed/Athletes_processed').show()
