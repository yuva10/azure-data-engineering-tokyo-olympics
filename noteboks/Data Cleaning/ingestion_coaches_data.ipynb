# %%
# %run "../Includes/Function"

# %%
from pyspark.sql.types import *
coaches_schema=StructType([
    StructField('Name',StringType(),True),
    StructField('NOC',StringType(),True),
    StructField('Discipline',StringType(),True),
    StructField('Event',StringType(),True)
])

# %%
coaches_raw=spark.read\
    .schema(coaches_schema)\
    .csv('dbfs:/mnt/olympicstokyoadlssa/raw/Dataset/Coaches.csv')
display(coaches_raw)

# %%
coaches_df1=coaches_raw.drop('Event')
display(coaches_df1)

# %%
coaches_df2=remove_accents_df(coaches_df1)
display(coaches_df2)

# %%
coaches_df2.groupBy('Discipline').count().show()

# %%
coaches_df2.write.mode('overwrite').parquet('dbfs:/mnt/olympicstokyoadlssa/processed/Coaches')
